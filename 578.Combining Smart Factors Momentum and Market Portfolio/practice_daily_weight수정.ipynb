# %% [markdown]
# ## Combining Smart Factors Momentum

# %% [markdown]
# ### Factor 선정
# 논문에 나와있는 Factor를 모두 선정하는 건 어려워서, 투자 가능한 ETF의 추종 지수 선정
#
# 1. [모멘텀] FnGuide 스마트 모멘텀 (ETF: Kindex 스마트 모멘텀)
# 2. [밸류] FnGuide 스마트 밸류 (ETF: Kindex 스마트 밸류)
# 3. [퀄리티] FnGuide 스마트 퀄리티 (ETF: Kindex 스마트 퀄리티)
# 4. [로우볼] FnGuide 스마트 로우볼 (ETF: Kindex 스마트 로우볼)
# 5. [하이베타] FnGuide 스마트 하이베타 (ETF: Kindex 스마트 하이베타)
#
# 각 지수 간단 설명
#
# FnGuide 스마트전략형 지수 시리즈
#   - Momentum 전략(FnGuide 스마트 모멘텀 지수),
#   - Value 전략(FnGuide 스마트 밸류 지수),
#   - Quality 전략(FnGuide 스마트 퀄리티 지수),
#   - Low Volatility 전략(FnGuide 스마트 로우볼 지수),
#   - High Beta 전략(FnGuide 스마트 하이베타 지수) 의 5개 지수로 구성
#
# 유니버스 : 코스피 유동시총 상위 200종목
#
# 각 지수의 지표값과 유동시가총액을 반영한 최적화법(Optimization)을 이용하여 시장과의 괴리를 낮추면서 장기적인 초과수익을 추구하는 지수
#
# #### A. Momentum 전략 지수
#
# 동일 업종에 속한 종목들의 수익률은 장기적으로 업종군의 평균 성과에 수령한다는 가정하에, 개별종목의 유니버스 대비 모멘텀과 속한 업종군 대비 모멘텀을 계산하여 종목을 선정합니다. 유니버스대비 모멘텀이 높으나, 업종 대비 모멘텀이 낮은 종목들은 업종 평균에 맞춰 추가 상승 여력이 있다고 가정하여 롱 포지션을 취하고, 유니버스 대비 모멘텀이 낮으나, 업종 대비 모멘텀이 높은 종목들은 업종 평균에 맞춰 하락할 가능성이 있다고 가정하여 숏 포지션을 취하여 지수를 구성합니다.
#
# #### B. Value 전략 지수
#
# DCF(Discounted Cash Flow) 밸류에이션 모델 중의 하나인, RIM 모델을 이용하여 향후 발생할 Residual Income(잉여 이익)을 할인하여 개별 종목의 적정 가치를 계산해, 현재 주가와 RIM 모델을 이용해 계산한 적정 가치의 밸류에이션 값 간의 괴리가 큰 저평가 종목을 우선 편입하여 구성하는 지수입니다.
#
# #### C. Quality 전략 지수
#
# 퀄리티 투자는 기업의 안정적인 이익실현의 측면과 퀄리티 스타일 측면의 두 가지 컨셉이 혼재되어 있는데 본 지수에서는 후자에 포커스를 두어 퀄리티 스타일 팩터를 결합하여 기업을 평가합니다. 팩터는 높은 ROIC 및 유동주식비율, 낮은 부채비율로 구성되어 있으며, 안정적인 재무구조와
# 지속가능한 수익력을 보유한 종목들을 편입하여 구성하는 지수입니다.
#
# #### D. Low Volatility 전략 지수
#
# 경기의 변동성이 심한 시장에서 상대적으로 주가 변동성이 낮은 종목들에 분산 투자하는 전략은 포트폴리오의 위험성을 낮추고 장기적으로 시장 초과 수익률을 기대할 수 있게 합니다. 유니버스에서 상대적으로 변동성이 낮은 종목들을 지수에 편입하여 적은 위험성으로 꾸준한 초과수익을 달성할 수 있도록 구성한 지수입니다.
#
# #### E. High Beta 전략 지수
#
# 베타가 높은 기업은 시장의 움직임에 대해 민감하게 반응하며, 시장이 상승할 때 더 큰 폭으로 수익을 낼 수 있습니다. 유니버스 내 종목들과 코스피200 지수의 베타 값을 산출하여 베타가 높은 종목들을 지수에 편입하여, 시장이 상승장에 들어설 때 보다 큰 수익을 얻을 수 있도록 지수를 구성하였습니다.
#
# URL:
# http://file.fnguide.com/fnindex/FnGuide_KIM_Smart_Strategy_Index_Series_Methodology_Book_%ED%95%9C%ED%88%AC_(20190701)_v3.2.pdf
#
# ### 상관관계가 너무 높아 다른 ETF의 차트 및 수익률을 보자
# #### F. FnGuide 고배당 Plus (ETF : KODEX 고배당, 20171017)
# #### G. FnGuide 모멘텀 Plus (ETF : KODEX 모멘텀Plus, 20160513)
# #### H. FnGuide 퀄리티 Plus (ETF : KODEX 퀄리티Plus, )
# #### I. FnGuide 밸류 Plus (ETF : KODEX 밸류Plus, )
# #### J. FnGuide 컨트래리안 (ETF : TIGER 가격조정, 20150428)
# #### K. ETF : KODEX 고배당
# #### ETF : KODEX Inverse 200
#
# 유가증권시장 및 코스닥시장 상장종목 시가총액 상위 300위 이내 종목 중, 정기변경 시점 기준으로 최근 2년간 수익률 상위 60종목 중에서 최근 1개월간 수익률 하락폭이 큰 30종목으로 지수 구성

# %% [markdown]
# ## 1. 종가 가져오기

# %%
# pykrx 이용
# !pip install pykrx
from pykrx import stock
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt

# %%
# Kindex 스마트 ETF
# 종목코드
# '322120' 퀄리티 - 상장일 : 20190416
# '322130' 로우볼 - 상장일 : 20190416
# '322150' 하이베타 - 상장일 : 20190416
# '272230' 밸류 - 상장일 : 20170711
# '272220' 모맨텀 - 상장일 : 20170711
# => 20190416 부터 시뮬레이션 가능

# 해당시점에 상장되어있는지 티커 확인
tickers = stock.get_etf_ticker_list("20190416")
names = []
for ticker in tickers:
    names.append(stock.get_etf_ticker_name(ticker))
df_tickers = pd.DataFrame([x for x in zip(tickers, names) ])

# %%
# Column 명 바꾸기
df_tickers = df_tickers.rename(columns={0:'종목코드', 1:'종목명'})

# %%
# 확인
df_tickers.head()
# Out:
#      종목코드                 종목명
# 0  292340  마이티 200커버드콜ATM레버리지
# 1  159800          마이티 코스피100
# 2  285000        KBSTAR 200IT
# 3  287300        KBSTAR 200건설
# 4  287310     KBSTAR 200경기소비재

# %%
# 우리의 ETF 있는지 확인
# str.contains 메서드 사용
df_tickers[df_tickers['종목명'].str.contains('스마트')]
# 확인 완료
# Out:
#        종목코드                       종목명
# 314  322130             KINDEX 스마트로우볼
# 315  272220             KINDEX 스마트모멘텀
# 316  272230              KINDEX 스마트밸류
# 317  322120             KINDEX 스마트퀄리티
# 318  322150            KINDEX 스마트하이베타
# 350  238670  ARIRANG 스마트베타Quality채권혼합

# %%
# 인버스 있는지 확인
df_tickers[df_tickers['종목명']=='KODEX 인버스']
# Out:
#        종목코드        종목명
# 268  114800  KODEX 인버스

# %%
# 벤치마크 지수 있는지 확인
df_tickers[df_tickers['종목명']=='KODEX 200']
# Out:
#        종목코드        종목명
# 253  069500  KODEX 200

# %%
df_tickers[df_tickers['종목명'].str.contains('스마트')].iloc[:5]
# Out:
#        종목코드             종목명
# 314  322130   KINDEX 스마트로우볼
# 315  272220   KINDEX 스마트모멘텀
# 316  272230    KINDEX 스마트밸류
# 317  322120   KINDEX 스마트퀄리티
# 318  322150  KINDEX 스마트하이베타

# %%
# 상관관계가 너무 높아 다른 ETF의 차트 및 수익률을 보자
# FnGuide 고배당 Plus (ETF : KODEX 고배당, 20171017)
# FnGuide 모멘텀 Plus (ETF : KODEX 모멘텀Plus, 20160513)
# FnGuide 퀄리티 Plus (ETF : KODEX 퀄리티Plus, )
# FnGuide 밸류 Plus (ETF : KODEX 밸류Plus, )

# FnGuide 컨트래리안 (ETF : TIGER 가격조정, 20150428)
# 유가증권시장 및 코스닥시장 상장종목 시가총액 상위 300위 이내 종목 중, 
# 정기변경 시점 기준으로 최근 2년간 수익률 상위 60종목 중에서 최근 1개월간 수익률 하락폭이 큰 30종목으로 
# 지수 구성

# %%
df_tickers[df_tickers['종목명'].str.contains('Plus')]
# Out:
#        종목코드               종목명
# 199  315930  KODEX Top5PlusTR
# 213  244620     KODEX 모멘텀Plus
# 231  244670      KODEX 밸류Plus
# 249  244660     KODEX 퀄리티Plus

# %%
df_tickers[df_tickers['종목명'].str.contains('가격')]
# Out:
#        종목코드         종목명
# 161  217790  TIGER 가격조정

# %%
df_tickers[df_tickers['종목명'].str.contains('KODEX 고배당')]
# 위 ETF 다 있음을 확인
# Out:
#        종목코드        종목명
# 204  279530  KODEX 고배당

# %%
df = df_tickers[df_tickers['종목명'].str.contains('스마트')].iloc[:5]
df = pd.concat([df, df_tickers[df_tickers['종목명'].str.contains('Plus')][1:]])

# %%
df
# Out:
#        종목코드             종목명
# 314  322130   KINDEX 스마트로우볼
# 315  272220   KINDEX 스마트모멘텀
# 316  272230    KINDEX 스마트밸류
# 317  322120   KINDEX 스마트퀄리티
# 318  322150  KINDEX 스마트하이베타
# 213  244620   KODEX 모멘텀Plus
# 231  244670    KODEX 밸류Plus
# 249  244660   KODEX 퀄리티Plus

# %%
df = pd.concat([df, df_tickers[df_tickers['종목명'].str.contains('가격')]])
df = pd.concat([df, df_tickers[df_tickers['종목명'].str.contains('KODEX 고배당')]])
df = pd.concat([df, df_tickers[df_tickers['종목명']=='KODEX 인버스']])
df = pd.concat([df, df_tickers[df_tickers['종목명']=='KODEX 200']])

# %%
df
# Out:
#        종목코드             종목명
# 314  322130   KINDEX 스마트로우볼
# 315  272220   KINDEX 스마트모멘텀
# 316  272230    KINDEX 스마트밸류
# 317  322120   KINDEX 스마트퀄리티
# 318  322150  KINDEX 스마트하이베타
# 213  244620   KODEX 모멘텀Plus
# 231  244670    KODEX 밸류Plus
# 249  244660   KODEX 퀄리티Plus
# 161  217790      TIGER 가격조정
# 204  279530       KODEX 고배당
# 268  114800       KODEX 인버스
# 253  069500       KODEX 200

# %%
# 데이터 시각화
stocks = dict()
legend = []
for a, b in df[['종목명', '종목코드']].itertuples(index=False):
    price = stock.get_etf_ohlcv_by_date("20190416", "20220423", b)
    stocks[a] = price['종가'].values[:].tolist()
    legend.append(a)
prices = pd.DataFrame(stocks)
prices.index = price.index

# import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 16
plt.figure(figsize=(16, 8))

plt.plot(prices)
plt.legend(legend, loc='upper left')

# %%
df_cumret = prices/prices.iloc[0]

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 16
plt.figure(figsize=(16, 8))

plt.plot(df_cumret)
plt.legend(legend, loc='upper left')

# %% [markdown]
# ## Weight 산정하기

# %%
# df와 df_cumret 세팅하면 그 이후 weight 계산하는 걸로 짜보자
# s_slow 계산

# 일별로 계산해보자
prices
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16          12645          12330         11290          12800
# 2019-04-17          12590          12305         11275          12775
# 2019-04-18          12420          12145         11115          12580
# 2019-04-19          12435          12150         11110          12615
# 2019-04-22          12430          12140         11070          12630
# ...                   ...            ...           ...            ...
# 2022-04-18          15375          15385         13890          15785
# 2022-04-19          15550          15575         14070          15955
# 2022-04-20          15575          15555         14085          15955
# 2022-04-21          15625          15650         14155          16045
# 2022-04-22          15505          15550         14040          15845
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16           10175          10260          9630          10725
# 2019-04-17           10145          10150          9575          10655
# 2019-04-18            9975           9995          9470          10445
# 2019-04-19           10010          10005          9435          10495
# 2019-04-22           10020          10005          9465          10465
# ...                    ...            ...           ...            ...
# 2022-04-18           13245          12820          9815          10195
# 2022-04-19           13400          12935          9850          10240
# 2022-04-20           13405          12970          9995          10375
# 2022-04-21           13505          13065          9960          10335
# 2022-04-22           13355          13005          9935          10255
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스  KODEX 200
# 날짜
# 2019-04-16       26390       9260       6545      29535
# 2019-04-17       26250       9290       6545      29515
# 2019-04-18       25885       9230       6650      29045
# 2019-04-19       25875       9255       6645      29050
# 2019-04-22       25910       9255       6650      29055
# ...                ...        ...        ...        ...
# 2022-04-18       23545      10660       4415      35835
# 2022-04-19       23725      10730       4365      36255
# 2022-04-20       23795      10750       4370      36225
# 2022-04-21       23915      10760       4350      36385
# 2022-04-22       23770      10795       4400      35985
#
# [747 rows x 12 columns]

# %%
# prices.iloc[0].name

# %%
# prices.iloc[0].name.month

# %%
# prices.shape

# %%
# 시작시점 일종가 추가
# month_prices = pd.DataFrame(prices.iloc[0]).T

# %%
# month_prices

# %%
# 시작시점 일종가 추가
# month_prices = pd.DataFrame(prices.iloc[0]).T

# for i in range(len(prices) - 1):
#     if prices.iloc[i].name.month != prices.iloc[i + 1].name.month:
#         month_prices = pd.concat([month_prices, pd.DataFrame(prices.iloc[i]).T])

# # 마지막 달 추가
# if month_prices.iloc[-1].name.month != prices.iloc[-1].name.month:
#     month_prices = pd.concat([month_prices, pd.DataFrame(prices.iloc[-1]).T])

month_prices = prices

# %%
month_prices.head()
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16          12645          12330         11290          12800
# 2019-04-17          12590          12305         11275          12775
# 2019-04-18          12420          12145         11115          12580
# 2019-04-19          12435          12150         11110          12615
# 2019-04-22          12430          12140         11070          12630
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16           10175          10260          9630          10725
# 2019-04-17           10145          10150          9575          10655
# 2019-04-18            9975           9995          9470          10445
# 2019-04-19           10010          10005          9435          10495
# 2019-04-22           10020          10005          9465          10465
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스  KODEX 200
# 날짜
# 2019-04-16       26390       9260       6545      29535
# 2019-04-17       26250       9290       6545      29515
# 2019-04-18       25885       9230       6650      29045
# 2019-04-19       25875       9255       6645      29050
# 2019-04-22       25910       9255       6650      29055

# %%
month_return = month_prices.pct_change(1)

# %%
month_return_without_index = month_return.drop(labels='KODEX 200', axis=1)

# %%
month_return.head()
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-04-17      -0.004350      -0.002028     -0.001329      -0.001953
# 2019-04-18      -0.013503      -0.013003     -0.014191      -0.015264
# 2019-04-19       0.001208       0.000412     -0.000450       0.002782
# 2019-04-22      -0.000402      -0.000823     -0.003600       0.001189
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-04-17       -0.002948      -0.010721     -0.005711      -0.006527
# 2019-04-18       -0.016757      -0.015271     -0.010966      -0.019709
# 2019-04-19        0.003509       0.001001     -0.003696       0.004787
# 2019-04-22        0.000999       0.000000      0.003180      -0.002859
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스  KODEX 200
# 날짜
# 2019-04-16         NaN        NaN        NaN        NaN
# 2019-04-17   -0.005305   0.003240   0.000000  -0.000677
# 2019-04-18   -0.013905  -0.006459   0.016043  -0.015924
# 2019-04-19   -0.000386   0.002709  -0.000752   0.000172
# 2019-04-22    0.001353   0.000000   0.000752   0.000172

# %%
month_return_without_index.head()
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-04-17      -0.004350      -0.002028     -0.001329      -0.001953
# 2019-04-18      -0.013503      -0.013003     -0.014191      -0.015264
# 2019-04-19       0.001208       0.000412     -0.000450       0.002782
# 2019-04-22      -0.000402      -0.000823     -0.003600       0.001189
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-04-17       -0.002948      -0.010721     -0.005711      -0.006527
# 2019-04-18       -0.016757      -0.015271     -0.010966      -0.019709
# 2019-04-19        0.003509       0.001001     -0.003696       0.004787
# 2019-04-22        0.000999       0.000000      0.003180      -0.002859
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스
# 날짜
# 2019-04-16         NaN        NaN        NaN
# 2019-04-17   -0.005305   0.003240   0.000000
# 2019-04-18   -0.013905  -0.006459   0.016043
# 2019-04-19   -0.000386   0.002709  -0.000752
# 2019-04-22    0.001353   0.000000   0.000752

# %%
s_slow = (1 + month_return_without_index).rolling(window=12, closed='left').apply(np.prod, raw=True) - 1
# https://stackoverflow.com/questions/15295434/how-to-calculate-rolling-cumulative-product-on-pandas-dataframe

# %%
# s_slow = s_slow.fillna(0)
s_slow.isnull().sum()
# Out:
# KINDEX 스마트로우볼     13
# KINDEX 스마트모멘텀     13
# KINDEX 스마트밸류      13
# KINDEX 스마트퀄리티     13
# KINDEX 스마트하이베타    13
# KODEX 모멘텀Plus     13
# KODEX 밸류Plus      13
# KODEX 퀄리티Plus     13
# TIGER 가격조정        13
# KODEX 고배당         13
# KODEX 인버스         13
# dtype: int64

# %%
s_fast = (month_return_without_index).rolling(window=1, closed='left').apply(np.prod, raw=True)
# s_fast = s_fast.fillna(0)

# %%
s_fast.head()
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-04-17            NaN            NaN           NaN            NaN
# 2019-04-18      -0.004350      -0.002028     -0.001329      -0.001953
# 2019-04-19      -0.013503      -0.013003     -0.014191      -0.015264
# 2019-04-22       0.001208       0.000412     -0.000450       0.002782
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-04-17             NaN            NaN           NaN            NaN
# 2019-04-18       -0.002948      -0.010721     -0.005711      -0.006527
# 2019-04-19       -0.016757      -0.015271     -0.010966      -0.019709
# 2019-04-22        0.003509       0.001001     -0.003696       0.004787
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스
# 날짜
# 2019-04-16         NaN        NaN        NaN
# 2019-04-17         NaN        NaN        NaN
# 2019-04-18   -0.005305   0.003240   0.000000
# 2019-04-19   -0.013905  -0.006459   0.016043
# 2019-04-22   -0.000386   0.002709  -0.000752

# %%
n = month_return_without_index.shape[1]
rank_sum = n*(n + 1)/2

# %%
#s_fast.abs().rank(axis=1, ascending=True).head()
s_fast[s_fast >= 0]
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-04-17            NaN            NaN           NaN            NaN
# 2019-04-18            NaN            NaN           NaN            NaN
# 2019-04-19            NaN            NaN           NaN            NaN
# 2019-04-22       0.001208       0.000412           NaN       0.002782
# ...                   ...            ...           ...            ...
# 2022-04-18            NaN            NaN           NaN            NaN
# 2022-04-19            NaN            NaN           NaN            NaN
# 2022-04-20       0.011382       0.012350      0.012959       0.010770
# 2022-04-21       0.001608            NaN      0.001066       0.000000
# 2022-04-22       0.003210       0.006107      0.004970       0.005641
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-04-17             NaN            NaN           NaN            NaN
# 2019-04-18             NaN            NaN           NaN            NaN
# 2019-04-19             NaN            NaN           NaN            NaN
# 2019-04-22        0.003509       0.001001           NaN       0.004787
# ...                    ...            ...           ...            ...
# 2022-04-18             NaN       0.002328      0.002577            NaN
# 2022-04-19             NaN            NaN      0.009254       0.004929
# 2022-04-20        0.011703       0.008970      0.003566       0.004414
# 2022-04-21        0.000373       0.002706      0.014721       0.013184
# 2022-04-22        0.007460       0.007325           NaN            NaN
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스
# 날짜
# 2019-04-16         NaN        NaN        NaN
# 2019-04-17         NaN        NaN        NaN
# 2019-04-18         NaN   0.003240   0.000000
# 2019-04-19         NaN        NaN   0.016043
# 2019-04-22         NaN   0.002709        NaN
# ...                ...        ...        ...
# 2022-04-18         NaN        NaN   0.012600
# 2022-04-19         NaN   0.002351        NaN
# 2022-04-20    0.007645   0.006567        NaN
# 2022-04-21    0.002950   0.001864   0.001145
# 2022-04-22    0.005043   0.000930        NaN
#
# [747 rows x 11 columns]

# %%
s_fast[s_fast >= 0].rank(axis=1, ascending=True).head()
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-04-17            NaN            NaN           NaN            NaN
# 2019-04-18            NaN            NaN           NaN            NaN
# 2019-04-19            NaN            NaN           NaN            NaN
# 2019-04-22            3.0            1.0           NaN            5.0
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-04-17             NaN            NaN           NaN            NaN
# 2019-04-18             NaN            NaN           NaN            NaN
# 2019-04-19             NaN            NaN           NaN            NaN
# 2019-04-22             6.0            2.0           NaN            7.0
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스
# 날짜
# 2019-04-16         NaN        NaN        NaN
# 2019-04-17         NaN        NaN        NaN
# 2019-04-18         NaN        2.0        1.0
# 2019-04-19         NaN        NaN        1.0
# 2019-04-22         NaN        4.0        NaN

# %%
s_fast[s_fast >= 0].rank(axis=1, ascending=True).sum(axis=1)
# Out:
# 날짜
# 2019-04-16     0.0
# 2019-04-17     0.0
# 2019-04-18     3.0
# 2019-04-19     1.0
# 2019-04-22    28.0
#               ...
# 2022-04-18     6.0
# 2022-04-19     6.0
# 2022-04-20    55.0
# 2022-04-21    55.0
# 2022-04-22    36.0
# Length: 747, dtype: float64

# %%
# s_fast.apply(np.sign).head()

# %%
# w_fast = s_fast[s_fast >= 0].rank(axis=1, ascending=True) * s_fast.apply(np.sign) / rank_sum
w_fast = s_fast[s_fast >= 0].rank(axis=1, ascending=True).div(s_fast[s_fast >= 0].rank(axis=1, ascending=True).sum(axis=1), axis=0)

# %%
w_fast
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-04-17            NaN            NaN           NaN            NaN
# 2019-04-18            NaN            NaN           NaN            NaN
# 2019-04-19            NaN            NaN           NaN            NaN
# 2019-04-22       0.107143       0.035714           NaN       0.178571
# ...                   ...            ...           ...            ...
# 2022-04-18            NaN            NaN           NaN            NaN
# 2022-04-19            NaN            NaN           NaN            NaN
# 2022-04-20       0.127273       0.163636      0.181818       0.109091
# 2022-04-21       0.090909            NaN      0.054545       0.018182
# 2022-04-22       0.055556       0.166667      0.083333       0.138889
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-04-17             NaN            NaN           NaN            NaN
# 2019-04-18             NaN            NaN           NaN            NaN
# 2019-04-19             NaN            NaN           NaN            NaN
# 2019-04-22        0.214286       0.071429           NaN       0.250000
# ...                    ...            ...           ...            ...
# 2022-04-18             NaN       0.166667      0.333333            NaN
# 2022-04-19             NaN            NaN      0.500000       0.333333
# 2022-04-20        0.145455       0.090909      0.018182       0.036364
# 2022-04-21        0.036364       0.127273      0.181818       0.163636
# 2022-04-22        0.222222       0.194444           NaN            NaN
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스
# 날짜
# 2019-04-16         NaN        NaN        NaN
# 2019-04-17         NaN        NaN        NaN
# 2019-04-18         NaN   0.666667   0.333333
# 2019-04-19         NaN        NaN   1.000000
# 2019-04-22         NaN   0.142857        NaN
# ...                ...        ...        ...
# 2022-04-18         NaN        NaN   0.500000
# 2022-04-19         NaN   0.166667        NaN
# 2022-04-20    0.072727   0.054545        NaN
# 2022-04-21    0.145455   0.109091   0.072727
# 2022-04-22    0.111111   0.027778        NaN
#
# [747 rows x 11 columns]

# %%
w_fast.sum(axis=1)
# Out:
# 날짜
# 2019-04-16    0.0
# 2019-04-17    0.0
# 2019-04-18    1.0
# 2019-04-19    1.0
# 2019-04-22    1.0
#              ...
# 2022-04-18    1.0
# 2022-04-19    1.0
# 2022-04-20    1.0
# 2022-04-21    1.0
# 2022-04-22    1.0
# Length: 747, dtype: float64

# %%
w_fast[w_fast.sum(axis=1)!=1].iloc[4].sum()
# Out:
# 1.0000000000000002

# %%
w_slow = s_slow[s_slow >= 0].rank(axis=1, ascending=True).div(s_slow[s_slow >= 0].rank(axis=1, ascending=True).sum(axis=1), axis=0)

# %%
w_slow
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-04-17            NaN            NaN           NaN            NaN
# 2019-04-18            NaN            NaN           NaN            NaN
# 2019-04-19            NaN            NaN           NaN            NaN
# 2019-04-22            NaN            NaN           NaN            NaN
# ...                   ...            ...           ...            ...
# 2022-04-18            NaN            NaN           NaN            NaN
# 2022-04-19            NaN            NaN           NaN            NaN
# 2022-04-20            NaN            NaN           NaN            NaN
# 2022-04-21            NaN            NaN           NaN            NaN
# 2022-04-22            NaN            NaN           NaN            NaN
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-04-17             NaN            NaN           NaN            NaN
# 2019-04-18             NaN            NaN           NaN            NaN
# 2019-04-19             NaN            NaN           NaN            NaN
# 2019-04-22             NaN            NaN           NaN            NaN
# ...                    ...            ...           ...            ...
# 2022-04-18             NaN       0.100000      0.300000            NaN
# 2022-04-19             NaN            NaN      0.333333            NaN
# 2022-04-20             NaN       0.133333      0.333333       0.066667
# 2022-04-21             NaN       0.066667      0.333333       0.200000
# 2022-04-22             NaN       0.066667      0.333333       0.133333
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스
# 날짜
# 2019-04-16         NaN        NaN        NaN
# 2019-04-17         NaN        NaN        NaN
# 2019-04-18         NaN        NaN        NaN
# 2019-04-19         NaN        NaN        NaN
# 2019-04-22         NaN        NaN        NaN
# ...                ...        ...        ...
# 2022-04-18         NaN   0.200000   0.400000
# 2022-04-19         NaN   0.166667   0.500000
# 2022-04-20         NaN   0.266667   0.200000
# 2022-04-21         NaN   0.133333   0.266667
# 2022-04-22         NaN   0.200000   0.266667
#
# [747 rows x 11 columns]

# %%
columns_name = []

# %%
# ret_slow = (month_return_without_index * s_slow.apply(np.sign)).sum(axis=1, min_count = month_return_without_index.shape[1]) / month_return_without_index.shape[1]
ret_slow = (month_return_without_index * (s_slow>=0)).sum(axis=1).div((s_slow>=0).sum(axis=1), axis=0)
columns_name.append('ret_slow')
df_ret = pd.DataFrame(ret_slow)
print(df_ret.shape)
len(columns_name)
# Out:
# (747, 1)
# 1

# %%
((s_slow>=0).sum(axis=1)==0).sum()
# Out:
# 14

# %%
df_ret.isnull().sum()
# Out:
# 0    14
# dtype: int64

# %%
ret_dyn_slow = (month_return_without_index * w_slow).sum(axis=1)
columns_name.append('ret_dyn_slow')
df_ret = pd.concat([df_ret, ret_dyn_slow], axis=1)
print(df_ret.shape)
len(columns_name)
# Out:
# (747, 2)
# 2

# %%
# ret_fast = (month_return_without_index * s_fast[s_fast>=0]).sum(axis=1,min_count = month_return_without_index.shape[1]) / month_return_without_index.shape[1]
ret_fast = (month_return_without_index * (s_fast>=0)).sum(axis=1).div((s_fast>=0).sum(axis=1), axis=0)
columns_name.append('ret_fast')
df_ret = pd.concat([df_ret, ret_fast], axis=1)
print(df_ret.shape)
len(columns_name)
# Out:
# (747, 3)
# 3

# %%
ret_dyn_fast = (month_return_without_index * w_fast).sum(axis=1)
columns_name.append('ret_dyn_fast')
df_ret = pd.concat([df_ret, ret_dyn_fast], axis=1)
print(df_ret.shape)
len(columns_name)
# Out:
# (747, 4)
# 4

# %%
ret_neutral = (ret_slow + ret_fast) / 2
columns_name.append('ret_neutral')
df_ret = pd.concat([df_ret, ret_neutral], axis=1)
print(df_ret.shape)
len(columns_name)
# Out:
# (747, 5)
# 5

# %%
ret_dyn_neutral = (month_return_without_index * 1/2 * (w_fast + w_slow)).sum(axis=1)
columns_name.append('ret_dyn_neutral')
df_ret = pd.concat([df_ret, ret_dyn_neutral], axis=1)
print(df_ret.shape)
len(columns_name)
# Out:
# (747, 6)
# 6

# %%
ret_blended = (month_return_without_index * (3/4 * (s_fast>=0) + 1/4 * (s_slow>=0))).sum(axis=1).div(((s_fast>=0) + (s_slow>=0)).sum(axis=1), axis=0)
columns_name.append('ret_blended')
df_ret = pd.concat([df_ret, ret_blended], axis=1)
print(df_ret.shape)
len(columns_name)
# Out:
# (747, 7)
# 7

# %%
ret_dyn_blended = (month_return_without_index * (3/4 * w_fast + 1/4 * w_slow)).sum(axis=1)
columns_name.append('ret_dyn_blended')
df_ret = pd.concat([df_ret, ret_dyn_blended], axis=1)
print(df_ret.shape)
len(columns_name)
# Out:
# (747, 8)
# 8

# %%
ret_index = month_return['KODEX 200']

# %%
columns_name
# Out:
# ['ret_slow',
#  'ret_dyn_slow',
#  'ret_fast',
#  'ret_dyn_fast',
#  'ret_neutral',
#  'ret_dyn_neutral',
#  'ret_blended',
#  'ret_dyn_blended']

# %%
df_ret.columns = columns_name

# %%
df_ret.head()
# Out:
#             ret_slow  ret_dyn_slow  ret_fast  ret_dyn_fast  ret_neutral  \
# 날짜
# 2019-04-16       NaN           0.0       NaN      0.000000          NaN
# 2019-04-17       NaN           0.0       NaN      0.000000          NaN
# 2019-04-18       NaN           0.0  0.004792      0.001042          NaN
# 2019-04-19       NaN           0.0 -0.000752     -0.000752          NaN
# 2019-04-22       NaN           0.0 -0.000271     -0.000361          NaN
#
#             ret_dyn_neutral  ret_blended  ret_dyn_blended
# 날짜
# 2019-04-16              0.0          NaN              0.0
# 2019-04-17              0.0          NaN              0.0
# 2019-04-18              0.0     0.003594              0.0
# 2019-04-19              0.0    -0.000564              0.0
# 2019-04-22              0.0    -0.000203              0.0

# %%
df_ret.isnull().sum(axis=0)
# Out:
# ret_slow           14
# ret_dyn_slow        0
# ret_fast            3
# ret_dyn_fast        0
# ret_neutral        15
# ret_dyn_neutral     0
# ret_blended         2
# ret_dyn_blended     0
# dtype: int64

# %%
df_ret = df_ret.fillna(0)

# %%
df_ret.isnull().sum(axis=0)
# Out:
# ret_slow           0
# ret_dyn_slow       0
# ret_fast           0
# ret_dyn_fast       0
# ret_neutral        0
# ret_dyn_neutral    0
# ret_blended        0
# ret_dyn_blended    0
# dtype: int64

# %%
df_ret.shape
# Out:
# (747, 8)

# %%
df_ret.corrwith(ret_index)
# Out:
# ret_slow          -0.057629
# ret_dyn_slow      -0.058559
# ret_fast          -0.024620
# ret_dyn_fast      -0.041027
# ret_neutral       -0.052620
# ret_dyn_neutral   -0.146809
# ret_blended        0.060277
# ret_dyn_blended   -0.141182
# dtype: float64

# %%
df_ret_with_index = pd.concat([df_ret, ret_index], axis=1)

# %%
df_ret_with_index.head()
# Out:
#             ret_slow  ret_dyn_slow  ret_fast  ret_dyn_fast  ret_neutral  \
# 날짜
# 2019-04-16       0.0           0.0  0.000000      0.000000          0.0
# 2019-04-17       0.0           0.0  0.000000      0.000000          0.0
# 2019-04-18       0.0           0.0  0.004792      0.001042          0.0
# 2019-04-19       0.0           0.0 -0.000752     -0.000752          0.0
# 2019-04-22       0.0           0.0 -0.000271     -0.000361          0.0
#
#             ret_dyn_neutral  ret_blended  ret_dyn_blended  KODEX 200
# 날짜
# 2019-04-16              0.0     0.000000              0.0        NaN
# 2019-04-17              0.0     0.000000              0.0  -0.000677
# 2019-04-18              0.0     0.003594              0.0  -0.015924
# 2019-04-19              0.0    -0.000564              0.0   0.000172
# 2019-04-22              0.0    -0.000203              0.0   0.000172

# %%
(1 + df_ret_with_index.dropna()).cumprod()
# Out:
#             ret_slow  ret_dyn_slow  ret_fast  ret_dyn_fast  ret_neutral  \
# 날짜
# 2019-04-17  1.000000      1.000000  1.000000      1.000000     1.000000
# 2019-04-18  1.000000      1.000000  1.004792      1.001042     1.000000
# 2019-04-19  1.000000      1.000000  1.004037      1.000289     1.000000
# 2019-04-22  1.000000      1.000000  1.003765      0.999928     1.000000
# 2019-04-23  1.000000      1.000000  1.002492      0.998162     1.000000
# ...              ...           ...       ...           ...          ...
# 2022-04-18  1.148006      1.169355  1.286654      1.394398     1.247995
# 2022-04-19  1.147549      1.165403  1.292893      1.400462     1.250773
# 2022-04-20  1.155265      1.173413  1.297701      1.402636     1.257303
# 2022-04-21  1.154415      1.170425  1.300640      1.404184     1.258264
# 2022-04-22  1.154393      1.172228  1.291995      1.393169     1.254071
#
#             ret_dyn_neutral  ret_blended  ret_dyn_blended  KODEX 200
# 날짜
# 2019-04-17         1.000000     1.000000         1.000000   0.999323
# 2019-04-18         1.000000     1.003594         1.000000   0.983410
# 2019-04-19         1.000000     1.003028         1.000000   0.983579
# 2019-04-22         1.000000     1.002824         1.000000   0.983748
# 2019-04-23         1.000000     1.001870         1.000000   0.985441
# ...                     ...          ...              ...        ...
# 2022-04-18         1.354239     1.260344         1.371678   1.213306
# 2022-04-19         1.357733     1.263688         1.375421   1.227527
# 2022-04-20         1.362986     1.267858         1.378835   1.226511
# 2022-04-21         1.360865     1.269894         1.377371   1.231928
# 2022-04-22         1.360553     1.265288         1.376660   1.218385
#
# [746 rows x 9 columns]

# %%
list(df_ret_with_index.columns)
# Out:
# ['ret_slow',
#  'ret_dyn_slow',
#  'ret_fast',
#  'ret_dyn_fast',
#  'ret_neutral',
#  'ret_dyn_neutral',
#  'ret_blended',
#  'ret_dyn_blended',
#  'KODEX 200']

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 16
plt.figure(figsize=(16, 8))

plt.plot((1 + df_ret_with_index.dropna()).cumprod())
plt.legend(list(df_ret_with_index.columns), loc='upper left')

# %%
df_ret_with_index = df_ret_with_index.dropna()

# %%
df_ret_with_index.head()
# Out:
#             ret_slow  ret_dyn_slow  ret_fast  ret_dyn_fast  ret_neutral  \
# 날짜
# 2019-04-17       0.0           0.0  0.000000      0.000000          0.0
# 2019-04-18       0.0           0.0  0.004792      0.001042          0.0
# 2019-04-19       0.0           0.0 -0.000752     -0.000752          0.0
# 2019-04-22       0.0           0.0 -0.000271     -0.000361          0.0
# 2019-04-23       0.0           0.0 -0.001268     -0.001766          0.0
#
#             ret_dyn_neutral  ret_blended  ret_dyn_blended  KODEX 200
# 날짜
# 2019-04-17              0.0     0.000000              0.0  -0.000677
# 2019-04-18              0.0     0.003594              0.0  -0.015924
# 2019-04-19              0.0    -0.000564              0.0   0.000172
# 2019-04-22              0.0    -0.000203              0.0   0.000172
# 2019-04-23              0.0    -0.000951              0.0   0.001721

# %%
df_ret_with_index.rolling(window=1, closed='left').sum().head()
# Out:
#             ret_slow  ret_dyn_slow  ret_fast  ret_dyn_fast  ret_neutral  \
# 날짜
# 2019-04-17       NaN           NaN       NaN           NaN          NaN
# 2019-04-18       0.0           0.0  0.000000      0.000000          0.0
# 2019-04-19       0.0           0.0  0.004792      0.001042          0.0
# 2019-04-22       0.0           0.0 -0.000752     -0.000752          0.0
# 2019-04-23       0.0           0.0 -0.000271     -0.000361          0.0
#
#             ret_dyn_neutral  ret_blended  ret_dyn_blended  KODEX 200
# 날짜
# 2019-04-17              NaN          NaN              NaN        NaN
# 2019-04-18              0.0     0.000000              0.0  -0.000677
# 2019-04-19              0.0     0.003594              0.0  -0.015924
# 2019-04-22              0.0    -0.000564              0.0   0.000172
# 2019-04-23              0.0    -0.000203              0.0   0.000172

# %%
i = 1
df_weight = (df_ret_with_index.rolling(window=i, closed='left').sum().sub(df_ret_with_index.rolling(window=i, closed='left').sum()['KODEX 200'] ,axis='index') > 0)*1

# %%
for i in range(2, 13):
    df_weight = df_weight + (df_ret_with_index.rolling(window=i, closed='left').sum().sub(df_ret_with_index.rolling(window=i, closed='left').sum()['KODEX 200'] ,axis='index') > 0)*1
df_weight = df_weight / 12

# %%
df_weight # 그달의 w_fport
# 앞 12개월 나중에 없애는것이 편함
# Out:
#             ret_slow  ret_dyn_slow  ret_fast  ret_dyn_fast  ret_neutral  \
# 날짜
# 2019-04-17  0.000000      0.000000  0.000000      0.000000     0.000000
# 2019-04-18  0.083333      0.083333  0.083333      0.083333     0.083333
# 2019-04-19  0.166667      0.166667  0.166667      0.166667     0.166667
# 2019-04-22  0.166667      0.166667  0.166667      0.166667     0.166667
# 2019-04-23  0.166667      0.166667  0.166667      0.166667     0.166667
# ...              ...           ...       ...           ...          ...
# 2022-04-18  0.916667      0.916667  0.666667      0.666667     0.666667
# 2022-04-19  0.833333      0.916667  0.583333      0.666667     0.583333
# 2022-04-20  0.250000      0.333333  0.500000      0.500000     0.500000
# 2022-04-21  0.666667      0.583333  0.500000      0.500000     0.500000
# 2022-04-22  0.333333      0.250000  0.416667      0.250000     0.416667
#
#             ret_dyn_neutral  ret_blended  ret_dyn_blended  KODEX 200
# 날짜
# 2019-04-17         0.000000     0.000000         0.000000        0.0
# 2019-04-18         0.083333     0.083333         0.083333        0.0
# 2019-04-19         0.166667     0.166667         0.166667        0.0
# 2019-04-22         0.166667     0.166667         0.166667        0.0
# 2019-04-23         0.166667     0.166667         0.166667        0.0
# ...                     ...          ...              ...        ...
# 2022-04-18         0.666667     0.666667         0.666667        0.0
# 2022-04-19         0.666667     0.583333         0.666667        0.0
# 2022-04-20         0.416667     0.416667         0.250000        0.0
# 2022-04-21         0.500000     0.500000         0.416667        0.0
# 2022-04-22         0.250000     0.416667         0.166667        0.0
#
# [746 rows x 9 columns]

# %%
df_weight.head()
# Out:
#             ret_slow  ret_dyn_slow  ret_fast  ret_dyn_fast  ret_neutral  \
# 날짜
# 2019-04-17  0.000000      0.000000  0.000000      0.000000     0.000000
# 2019-04-18  0.083333      0.083333  0.083333      0.083333     0.083333
# 2019-04-19  0.166667      0.166667  0.166667      0.166667     0.166667
# 2019-04-22  0.166667      0.166667  0.166667      0.166667     0.166667
# 2019-04-23  0.166667      0.166667  0.166667      0.166667     0.166667
#
#             ret_dyn_neutral  ret_blended  ret_dyn_blended  KODEX 200
# 날짜
# 2019-04-17         0.000000     0.000000         0.000000        0.0
# 2019-04-18         0.083333     0.083333         0.083333        0.0
# 2019-04-19         0.166667     0.166667         0.166667        0.0
# 2019-04-22         0.166667     0.166667         0.166667        0.0
# 2019-04-23         0.166667     0.166667         0.166667        0.0

# %%
# 최종 return combining index
df_ret_combine_index = df_ret_with_index * df_weight + (1 - df_weight).mul(df_ret_with_index.loc[:, 'KODEX 200'], axis=0)

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 16
plt.figure(figsize=(16, 8))

plt.plot((1 + df_ret_combine_index.iloc[12:]).cumprod())
plt.legend(list(df_ret_combine_index.columns), loc='upper left')

# %% [markdown]
# # 통계 계산 및 시각화
# ### MDD 계산

# %%
def drawdown(returns):
    cumulative = (1 + returns).cumprod()
    highwatermark = cumulative.cummax()
    drawdown = (cumulative /  highwatermark) - 1
    return drawdown

def maximum_drawdown(returns):
    return np.min(drawdown(returns))

# %%
df_ret_combine_index.apply(drawdown)
# Out:
#             ret_slow  ret_dyn_slow  ret_fast  ret_dyn_fast  ret_neutral  \
# 날짜
# 2019-04-17  0.000000      0.000000  0.000000      0.000000     0.000000
# 2019-04-18 -0.014597     -0.014597 -0.014198     -0.014510    -0.014597
# 2019-04-19 -0.014456     -0.014456 -0.014180     -0.014492    -0.014456
# 2019-04-22 -0.014314     -0.014314 -0.014083     -0.014410    -0.014314
# 2019-04-23 -0.012901     -0.012901 -0.012878     -0.013287    -0.012901
# ...              ...           ...       ...           ...          ...
# 2022-04-18 -0.264150     -0.252852 -0.193761     -0.196951    -0.220407
# 2022-04-19 -0.262956     -0.254436 -0.187543     -0.191486    -0.215588
# 2022-04-20 -0.262175     -0.253140 -0.186369     -0.191193    -0.213864
# 2022-04-21 -0.261450     -0.252874 -0.183651     -0.188960    -0.211828
# 2022-04-22 -0.266868     -0.258747 -0.191146     -0.197238    -0.217977
#
#             ret_dyn_neutral  ret_blended  ret_dyn_blended  KODEX 200
# 날짜
# 2019-04-17         0.000000     0.000000         0.000000   0.000000
# 2019-04-18        -0.014597    -0.014298        -0.014597  -0.015924
# 2019-04-19        -0.014456    -0.014249        -0.014456  -0.015755
# 2019-04-22        -0.014314    -0.014141        -0.014314  -0.015585
# 2019-04-23        -0.012901    -0.012883        -0.012901  -0.013891
# ...                     ...          ...              ...        ...
# 2022-04-18        -0.209202    -0.245070        -0.203282  -0.190352
# 2022-04-19        -0.204752    -0.240215        -0.198720  -0.180863
# 2022-04-20        -0.203854    -0.239537        -0.198720  -0.181541
# 2022-04-21        -0.202716    -0.237247        -0.197010  -0.177926
# 2022-04-22        -0.209335    -0.243292        -0.204436  -0.186963
#
# [746 rows x 9 columns]

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 16
plt.figure(figsize=(16, 8))

plt.title("Drawdown Chart")
plt.plot(df_ret_combine_index.apply(drawdown))
plt.legend(list(df_ret_combine_index.columns), loc='upper left')

# %%
# MDD 계산
df_ret_combine_index.apply(maximum_drawdown)
# Out:
# ret_slow          -0.266868
# ret_dyn_slow      -0.258747
# ret_fast          -0.196279
# ret_dyn_fast      -0.197867
# ret_neutral       -0.220893
# ret_dyn_neutral   -0.210181
# ret_blended       -0.245451
# ret_dyn_blended   -0.204436
# KODEX 200         -0.347518
# dtype: float64

# %%
(1+ df_ret_combine_index).cumprod().iloc[-1]
# Out:
# ret_slow           1.365971
# ret_dyn_slow       1.346228
# ret_fast           1.348627
# ret_dyn_fast       1.450701
# ret_neutral        1.368750
# ret_dyn_neutral    1.422830
# ret_blended        1.216754
# ret_dyn_blended    1.423072
# KODEX 200          1.218385
# Name: 2022-04-22 00:00:00, dtype: float64

# %%
# 연율화
(1+ df_ret_combine_index).cumprod().iloc[-1].pow(252/df_ret_combine_index.shape[0])-1
# Out:
# ret_slow           0.111098
# ret_dyn_slow       0.105647
# ret_fast           0.106312
# ret_dyn_fast       0.133917
# ret_neutral        0.111861
# ret_dyn_neutral    0.126511
# ret_blended        0.068518
# ret_dyn_blended    0.126575
# KODEX 200          0.069001
# Name: 2022-04-22 00:00:00, dtype: float64

# %%
# pd.Series -> pd.DataFrame
df_stat = ((1+ df_ret_combine_index).cumprod().iloc[-1].pow(252/df_ret_combine_index.shape[0])-1).to_frame(name='CAGR')

# %%
df_stat['MDD'] = df_ret_combine_index.apply(maximum_drawdown)

# %%
df_stat
# Out:
#                      CAGR       MDD
# ret_slow         0.111098 -0.266868
# ret_dyn_slow     0.105647 -0.258747
# ret_fast         0.106312 -0.196279
# ret_dyn_fast     0.133917 -0.197867
# ret_neutral      0.111861 -0.220893
# ret_dyn_neutral  0.126511 -0.210181
# ret_blended      0.068518 -0.245451
# ret_dyn_blended  0.126575 -0.204436
# KODEX 200        0.069001 -0.347518

# %% [markdown]
# ### Market - Portfolio 비중 계산

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 16
plt.figure(figsize=(16, 8))

df_weight['ret_dyn_fast'].plot.area()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 16
plt.figure(figsize=(16, 8))

df_weight['ret_dyn_blended'].plot.area() # ret_fast와 비중 큰 차이 없어보임
# Out:
# <AxesSubplot:xlabel='날짜'>

# %% [markdown]
# ### 수익률 분포

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 16
plt.figure(figsize=(24, 16))
df_ret_combine_index.plot.box()
# Out:
# <AxesSubplot:>

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 16
plt.figure(figsize=(24, 16))

df_ret_combine_index.plot(kind='kde')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title("수익률 분포")
plt.xlabel('수익률(%, 일별)')
plt.show()

# %%
## QQplot 그리기
import scipy.stats as stats

fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(1,1,1)
stats.probplot(df_ret_combine_index['ret_dyn_fast'], dist=stats.norm, plot=ax)
plt.show()

# %% [markdown]
# ### 그래서 어떻게 투자하라고? (ETF당 Weight 계산)
# #### ret_dyn_fast 기준

# %%
df_weight['ret_dyn_fast']
# Out:
# 날짜
# 2019-04-17    0.000000
# 2019-04-18    0.083333
# 2019-04-19    0.166667
# 2019-04-22    0.166667
# 2019-04-23    0.166667
#                 ...
# 2022-04-18    0.666667
# 2022-04-19    0.666667
# 2022-04-20    0.500000
# 2022-04-21    0.500000
# 2022-04-22    0.250000
# Name: ret_dyn_fast, Length: 746, dtype: float64

# %%
# ret_fast = (month_return_without_index * (s_fast>=0)).sum(axis=1).div((s_fast>=0).count(axis=1), axis=0)
w_fast.head()
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-04-17            NaN            NaN           NaN            NaN
# 2019-04-18            NaN            NaN           NaN            NaN
# 2019-04-19            NaN            NaN           NaN            NaN
# 2019-04-22       0.107143       0.035714           NaN       0.178571
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-04-17             NaN            NaN           NaN            NaN
# 2019-04-18             NaN            NaN           NaN            NaN
# 2019-04-19             NaN            NaN           NaN            NaN
# 2019-04-22        0.214286       0.071429           NaN           0.25
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스
# 날짜
# 2019-04-16         NaN        NaN        NaN
# 2019-04-17         NaN        NaN        NaN
# 2019-04-18         NaN   0.666667   0.333333
# 2019-04-19         NaN        NaN   1.000000
# 2019-04-22         NaN   0.142857        NaN

# %%
w_fast.sum(axis=1)
# Out:
# 날짜
# 2019-04-16    0.0
# 2019-04-17    0.0
# 2019-04-18    1.0
# 2019-04-19    1.0
# 2019-04-22    1.0
#              ...
# 2022-04-18    1.0
# 2022-04-19    1.0
# 2022-04-20    1.0
# 2022-04-21    1.0
# 2022-04-22    1.0
# Length: 747, dtype: float64

# %%
(w_fast.sum(axis=1)!=1).sum()
# Out:
# 93

# %%
w_fast[(w_fast.sum(axis=1) * df_weight['ret_dyn_fast'] + (1 - df_weight['ret_dyn_fast']))!=1]
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-05-15            NaN       0.066667      0.088889       0.044444
# 2019-05-28       0.069444       0.166667      0.194444       0.138889
# 2019-07-31       0.054545       0.109091      0.090909       0.181818
# 2019-09-18            NaN            NaN      0.027778       0.111111
# 2019-09-20       0.095238       0.285714      0.142857       0.190476
# 2019-09-23       0.127273       0.109091      0.163636       0.072727
# 2019-10-22       0.285714       0.238095      0.190476       0.142857
# 2019-10-29       0.055556       0.138889      0.194444       0.222222
# 2019-11-07       0.027778       0.166667      0.083333       0.138889
# 2019-12-10       0.214286       0.142857      0.250000       0.071429
# 2019-12-11       0.072727       0.109091      0.145455       0.127273
# 2020-01-30       0.072727       0.127273      0.109091       0.145455
# 2020-03-04       0.033333       0.088889      0.066667       0.133333
# 2020-03-11       0.107143       0.214286      0.142857       0.250000
# 2020-03-23       0.072727       0.109091      0.054545       0.036364
# 2020-06-17       0.127273       0.163636      0.145455       0.109091
# 2020-10-05       0.036364       0.127273      0.072727       0.054545
# 2021-02-24            NaN            NaN           NaN            NaN
# 2021-03-18            NaN            NaN           NaN            NaN
# 2021-04-23       0.027778       0.083333      0.055556            NaN
# 2021-04-26       0.045455       0.030303      0.106061       0.090909
# 2021-07-23       0.163636       0.145455      0.109091       0.090909
# 2021-08-19       0.066667       0.155556      0.111111       0.088889
# 2021-08-30       0.111111            NaN           NaN       0.041667
# 2021-09-02       0.090909       0.018182      0.145455       0.036364
# 2021-10-08       0.036364       0.072727      0.054545       0.109091
# 2021-10-12            NaN            NaN           NaN       0.190476
# 2021-10-14       0.054545       0.090909      0.036364       0.109091
# 2021-10-18       0.145455       0.127273      0.054545       0.163636
# 2021-11-10       0.214286       0.071429      0.107143       0.178571
# 2021-11-25            NaN            NaN           NaN            NaN
# 2021-12-02       0.054545       0.181818      0.109091       0.127273
# 2021-12-10            NaN       0.055556      0.027778       0.138889
# 2022-02-21            NaN            NaN           NaN            NaN
# 2022-03-11       0.145455       0.127273      0.072727       0.109091
# 2022-04-06            NaN            NaN           NaN       0.194444
# 2022-04-15            NaN            NaN           NaN            NaN
# 2022-04-19            NaN            NaN           NaN            NaN
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-05-15        0.133333       0.200000      0.177778            NaN
# 2019-05-28        0.069444       0.222222      0.069444            NaN
# 2019-07-31        0.145455       0.163636      0.072727       0.036364
# 2019-09-18        0.055556       0.166667      0.194444       0.222222
# 2019-09-20        0.238095       0.047619           NaN            NaN
# 2019-09-23        0.145455       0.090909      0.036364       0.018182
# 2019-10-22        0.095238            NaN           NaN            NaN
# 2019-10-29        0.111111       0.166667      0.083333            NaN
# 2019-11-07        0.111111            NaN      0.194444       0.222222
# 2019-12-10        0.178571       0.107143      0.035714            NaN
# 2019-12-11        0.181818       0.018182      0.036364       0.054545
# 2020-01-30        0.090909       0.181818      0.163636       0.054545
# 2020-03-04        0.155556            NaN      0.177778       0.111111
# 2020-03-11        0.178571       0.035714           NaN       0.071429
# 2020-03-23        0.090909       0.181818      0.127273       0.145455
# 2020-06-17        0.181818       0.090909      0.054545       0.072727
# 2020-10-05        0.109091       0.181818      0.163636       0.090909
# 2021-02-24             NaN            NaN      0.500000            NaN
# 2021-03-18             NaN       0.190476      0.142857       0.238095
# 2021-04-23        0.111111       0.194444      0.222222            NaN
# 2021-04-26        0.121212       0.151515      0.136364       0.075758
# 2021-07-23        0.127273       0.036364      0.072727       0.018182
# 2021-08-19        0.133333       0.022222      0.177778       0.200000
# 2021-08-30             NaN       0.083333      0.222222       0.138889
# 2021-09-02        0.072727       0.181818      0.109091       0.054545
# 2021-10-08        0.090909       0.145455      0.127273       0.181818
# 2021-10-12        0.047619       0.238095           NaN            NaN
# 2021-10-14        0.145455       0.181818      0.127273       0.072727
# 2021-10-18        0.090909       0.181818      0.109091       0.072727
# 2021-11-10        0.142857       0.250000           NaN            NaN
# 2021-11-25             NaN       0.500000           NaN            NaN
# 2021-12-02        0.163636       0.072727      0.090909       0.036364
# 2021-12-10        0.111111       0.083333      0.166667       0.222222
# 2022-02-21             NaN       0.285714      0.238095       0.190476
# 2022-03-11        0.054545       0.036364      0.181818       0.090909
# 2022-04-06        0.083333       0.222222      0.166667       0.055556
# 2022-04-15             NaN       0.190476      0.238095       0.285714
# 2022-04-19             NaN            NaN      0.500000       0.333333
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스
# 날짜
# 2019-04-16         NaN        NaN        NaN
# 2019-05-15    0.155556   0.022222   0.111111
# 2019-05-28         NaN        NaN   0.069444
# 2019-07-31    0.127273   0.018182        NaN
# 2019-09-18    0.138889   0.083333        NaN
# 2019-09-20         NaN        NaN        NaN
# 2019-09-23    0.181818   0.054545        NaN
# 2019-10-22         NaN   0.047619        NaN
# 2019-10-29         NaN   0.027778        NaN
# 2019-11-07    0.055556        NaN        NaN
# 2019-12-10         NaN        NaN        NaN
# 2019-12-11    0.163636   0.090909        NaN
# 2020-01-30    0.018182   0.036364        NaN
# 2020-03-04    0.200000   0.033333        NaN
# 2020-03-11         NaN        NaN        NaN
# 2020-03-23    0.163636   0.018182        NaN
# 2020-06-17    0.036364   0.018182        NaN
# 2020-10-05    0.145455   0.018182        NaN
# 2021-02-24    0.333333        NaN   0.166667
# 2021-03-18    0.095238   0.047619   0.285714
# 2021-04-23    0.138889   0.166667        NaN
# 2021-04-26    0.060606   0.166667   0.015152
# 2021-07-23    0.181818   0.054545        NaN
# 2021-08-19         NaN   0.044444        NaN
# 2021-08-30    0.166667   0.194444   0.041667
# 2021-09-02    0.127273   0.163636        NaN
# 2021-10-08    0.163636   0.018182        NaN
# 2021-10-12    0.285714   0.142857   0.095238
# 2021-10-14    0.163636   0.018182        NaN
# 2021-10-18    0.018182   0.036364        NaN
# 2021-11-10         NaN   0.035714        NaN
# 2021-11-25         NaN   0.333333   0.166667
# 2021-12-02    0.145455   0.018182        NaN
# 2021-12-10         NaN   0.194444        NaN
# 2022-02-21    0.142857   0.047619   0.095238
# 2022-03-11    0.163636   0.018182        NaN
# 2022-04-06    0.138889   0.027778   0.111111
# 2022-04-15    0.142857   0.047619   0.095238
# 2022-04-19         NaN   0.166667        NaN

# %%
df_weight_ret_dyn_fast = (w_fast.mul(df_weight['ret_dyn_fast'], axis=0))
df_weight_ret_dyn_fast['KODEX 200'] = 1 - df_weight['ret_dyn_fast']

# %%
df_weight_ret_dyn_fast
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-04-17            NaN            NaN           NaN            NaN
# 2019-04-18            NaN            NaN           NaN            NaN
# 2019-04-19            NaN            NaN           NaN            NaN
# 2019-04-22       0.017857       0.005952           NaN       0.029762
# ...                   ...            ...           ...            ...
# 2022-04-18            NaN            NaN           NaN            NaN
# 2022-04-19            NaN            NaN           NaN            NaN
# 2022-04-20       0.063636       0.081818      0.090909       0.054545
# 2022-04-21       0.045455            NaN      0.027273       0.009091
# 2022-04-22       0.013889       0.041667      0.020833       0.034722
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-04-17             NaN            NaN           NaN            NaN
# 2019-04-18             NaN            NaN           NaN            NaN
# 2019-04-19             NaN            NaN           NaN            NaN
# 2019-04-22        0.035714       0.011905           NaN       0.041667
# ...                    ...            ...           ...            ...
# 2022-04-18             NaN       0.111111      0.222222            NaN
# 2022-04-19             NaN            NaN      0.333333       0.222222
# 2022-04-20        0.072727       0.045455      0.009091       0.018182
# 2022-04-21        0.018182       0.063636      0.090909       0.081818
# 2022-04-22        0.055556       0.048611           NaN            NaN
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스  KODEX 200
# 날짜
# 2019-04-16         NaN        NaN        NaN        NaN
# 2019-04-17         NaN        NaN        NaN   1.000000
# 2019-04-18         NaN   0.055556   0.027778   0.916667
# 2019-04-19         NaN        NaN   0.166667   0.833333
# 2019-04-22         NaN   0.023810        NaN   0.833333
# ...                ...        ...        ...        ...
# 2022-04-18         NaN        NaN   0.333333   0.333333
# 2022-04-19         NaN   0.111111        NaN   0.333333
# 2022-04-20    0.036364   0.027273        NaN   0.500000
# 2022-04-21    0.072727   0.054545   0.036364   0.500000
# 2022-04-22    0.027778   0.006944        NaN   0.750000
#
# [747 rows x 12 columns]

# %%
df_weight_ret_dyn_fast.sum(axis=1)
# Out:
# 날짜
# 2019-04-16    0.0
# 2019-04-17    1.0
# 2019-04-18    1.0
# 2019-04-19    1.0
# 2019-04-22    1.0
#              ...
# 2022-04-18    1.0
# 2022-04-19    1.0
# 2022-04-20    1.0
# 2022-04-21    1.0
# 2022-04-22    1.0
# Length: 747, dtype: float64

# %%
# weight 합이 1이 아닌 날짜 수
(df_weight_ret_dyn_fast.sum(axis=1)!=1).sum()
# Out:
# 60

# %%
df_weight_ret_dyn_fast.sum().sum()
# Out:
# 746.0

# %%
# 평균
df_weight_ret_dyn_fast.sum(axis=1)[1:].mean()
# Out:
# 1.0

# %%
df_weight_ret_dyn_fast.sum(axis=1)[1:].std()
# Out:
# 3.1243386349831855e-17

# %%
df_weight_ret_dyn_fast.head()
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-04-17            NaN            NaN           NaN            NaN
# 2019-04-18            NaN            NaN           NaN            NaN
# 2019-04-19            NaN            NaN           NaN            NaN
# 2019-04-22       0.017857       0.005952           NaN       0.029762
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-04-17             NaN            NaN           NaN            NaN
# 2019-04-18             NaN            NaN           NaN            NaN
# 2019-04-19             NaN            NaN           NaN            NaN
# 2019-04-22        0.035714       0.011905           NaN       0.041667
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스  KODEX 200
# 날짜
# 2019-04-16         NaN        NaN        NaN        NaN
# 2019-04-17         NaN        NaN        NaN   1.000000
# 2019-04-18         NaN   0.055556   0.027778   0.916667
# 2019-04-19         NaN        NaN   0.166667   0.833333
# 2019-04-22         NaN   0.023810        NaN   0.833333

# %%
df_weight_ret_dyn_fast = df_weight_ret_dyn_fast[1:].fillna(0)

# %%
df_weight_ret_dyn_fast
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-17       0.000000       0.000000      0.000000       0.000000
# 2019-04-18       0.000000       0.000000      0.000000       0.000000
# 2019-04-19       0.000000       0.000000      0.000000       0.000000
# 2019-04-22       0.017857       0.005952      0.000000       0.029762
# 2019-04-23       0.000000       0.000000      0.000000       0.029762
# ...                   ...            ...           ...            ...
# 2022-04-18       0.000000       0.000000      0.000000       0.000000
# 2022-04-19       0.000000       0.000000      0.000000       0.000000
# 2022-04-20       0.063636       0.081818      0.090909       0.054545
# 2022-04-21       0.045455       0.000000      0.027273       0.009091
# 2022-04-22       0.013889       0.041667      0.020833       0.034722
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-17        0.000000       0.000000      0.000000       0.000000
# 2019-04-18        0.000000       0.000000      0.000000       0.000000
# 2019-04-19        0.000000       0.000000      0.000000       0.000000
# 2019-04-22        0.035714       0.011905      0.000000       0.041667
# 2019-04-23        0.023810       0.008929      0.041667       0.000000
# ...                    ...            ...           ...            ...
# 2022-04-18        0.000000       0.111111      0.222222       0.000000
# 2022-04-19        0.000000       0.000000      0.333333       0.222222
# 2022-04-20        0.072727       0.045455      0.009091       0.018182
# 2022-04-21        0.018182       0.063636      0.090909       0.081818
# 2022-04-22        0.055556       0.048611      0.000000       0.000000
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스  KODEX 200
# 날짜
# 2019-04-17    0.000000   0.000000   0.000000   1.000000
# 2019-04-18    0.000000   0.055556   0.027778   0.916667
# 2019-04-19    0.000000   0.000000   0.166667   0.833333
# 2019-04-22    0.000000   0.023810   0.000000   0.833333
# 2019-04-23    0.035714   0.008929   0.017857   0.833333
# ...                ...        ...        ...        ...
# 2022-04-18    0.000000   0.000000   0.333333   0.333333
# 2022-04-19    0.000000   0.111111   0.000000   0.333333
# 2022-04-20    0.036364   0.027273   0.000000   0.500000
# 2022-04-21    0.072727   0.054545   0.036364   0.500000
# 2022-04-22    0.027778   0.006944   0.000000   0.750000
#
# [746 rows x 12 columns]

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 16
plt.figure(figsize=(64, 8))

df_weight_ret_dyn_fast.plot.area()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title("ETF별 비중")
plt.xlabel('날짜')
plt.show()

# %% [markdown]
# #### 맞는지 체크해보자

# %%
df_ret_combine_index
# Out:
#             ret_slow  ret_dyn_slow  ret_fast  ret_dyn_fast  ret_neutral  \
# 날짜
# 2019-04-17 -0.000677     -0.000677 -0.000677     -0.000677    -0.000677
# 2019-04-18 -0.014597     -0.014597 -0.014198     -0.014510    -0.014597
# 2019-04-19  0.000143      0.000143  0.000018      0.000018     0.000143
# 2019-04-22  0.000143      0.000143  0.000098      0.000083     0.000143
# 2019-04-23  0.001434      0.001434  0.001223      0.001140     0.001434
# ...              ...           ...       ...           ...          ...
# 2022-04-18  0.000784      0.001957  0.000450      0.001141     0.000624
# 2022-04-19  0.001622     -0.002121  0.007712      0.006806     0.006182
# 2022-04-20  0.001060      0.001739  0.001446      0.000362     0.002197
# 2022-04-21  0.000982      0.000355  0.003341      0.002760     0.002591
# 2022-04-22 -0.007335     -0.007860 -0.009182     -0.010206    -0.007802
#
#             ret_dyn_neutral  ret_blended  ret_dyn_blended  KODEX 200
# 날짜
# 2019-04-17        -0.000677    -0.000677    -6.771627e-04  -0.000677
# 2019-04-18        -0.014597    -0.014298    -1.459710e-02  -0.015924
# 2019-04-19         0.000143     0.000049     1.434556e-04   0.000172
# 2019-04-22         0.000143     0.000110     1.434309e-04   0.000172
# 2019-04-23         0.001434     0.001276     1.434062e-03   0.001721
# ...                     ...          ...              ...        ...
# 2022-04-18         0.001240     0.000505     1.190633e-03   0.000838
# 2022-04-19         0.005627     0.006431     5.726020e-03   0.011720
# 2022-04-20         0.001129     0.000892    -1.167421e-07  -0.000827
# 2022-04-21         0.001430     0.003012     2.134137e-03   0.004417
# 2022-04-22        -0.008302    -0.007924    -9.247262e-03  -0.010994
#
# [746 rows x 9 columns]

# %%
prices
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16          12645          12330         11290          12800
# 2019-04-17          12590          12305         11275          12775
# 2019-04-18          12420          12145         11115          12580
# 2019-04-19          12435          12150         11110          12615
# 2019-04-22          12430          12140         11070          12630
# ...                   ...            ...           ...            ...
# 2022-04-18          15375          15385         13890          15785
# 2022-04-19          15550          15575         14070          15955
# 2022-04-20          15575          15555         14085          15955
# 2022-04-21          15625          15650         14155          16045
# 2022-04-22          15505          15550         14040          15845
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16           10175          10260          9630          10725
# 2019-04-17           10145          10150          9575          10655
# 2019-04-18            9975           9995          9470          10445
# 2019-04-19           10010          10005          9435          10495
# 2019-04-22           10020          10005          9465          10465
# ...                    ...            ...           ...            ...
# 2022-04-18           13245          12820          9815          10195
# 2022-04-19           13400          12935          9850          10240
# 2022-04-20           13405          12970          9995          10375
# 2022-04-21           13505          13065          9960          10335
# 2022-04-22           13355          13005          9935          10255
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스  KODEX 200
# 날짜
# 2019-04-16       26390       9260       6545      29535
# 2019-04-17       26250       9290       6545      29515
# 2019-04-18       25885       9230       6650      29045
# 2019-04-19       25875       9255       6645      29050
# 2019-04-22       25910       9255       6650      29055
# ...                ...        ...        ...        ...
# 2022-04-18       23545      10660       4415      35835
# 2022-04-19       23725      10730       4365      36255
# 2022-04-20       23795      10750       4370      36225
# 2022-04-21       23915      10760       4350      36385
# 2022-04-22       23770      10795       4400      35985
#
# [747 rows x 12 columns]

# %%
prices.pct_change()
# Out:
#             KINDEX 스마트로우볼  KINDEX 스마트모멘텀  KINDEX 스마트밸류  KINDEX 스마트퀄리티  \
# 날짜
# 2019-04-16            NaN            NaN           NaN            NaN
# 2019-04-17      -0.004350      -0.002028     -0.001329      -0.001953
# 2019-04-18      -0.013503      -0.013003     -0.014191      -0.015264
# 2019-04-19       0.001208       0.000412     -0.000450       0.002782
# 2019-04-22      -0.000402      -0.000823     -0.003600       0.001189
# ...                   ...            ...           ...            ...
# 2022-04-18      -0.000325      -0.000974     -0.001438      -0.000317
# 2022-04-19       0.011382       0.012350      0.012959       0.010770
# 2022-04-20       0.001608      -0.001284      0.001066       0.000000
# 2022-04-21       0.003210       0.006107      0.004970       0.005641
# 2022-04-22      -0.007680      -0.006390     -0.008124      -0.012465
#
#             KINDEX 스마트하이베타  KODEX 모멘텀Plus  KODEX 밸류Plus  KODEX 퀄리티Plus  \
# 날짜
# 2019-04-16             NaN            NaN           NaN            NaN
# 2019-04-17       -0.002948      -0.010721     -0.005711      -0.006527
# 2019-04-18       -0.016757      -0.015271     -0.010966      -0.019709
# 2019-04-19        0.003509       0.001001     -0.003696       0.004787
# 2019-04-22        0.000999       0.000000      0.003180      -0.002859
# ...                    ...            ...           ...            ...
# 2022-04-18       -0.002260      -0.007356      0.009254       0.004929
# 2022-04-19        0.011703       0.008970      0.003566       0.004414
# 2022-04-20        0.000373       0.002706      0.014721       0.013184
# 2022-04-21        0.007460       0.007325     -0.003502      -0.003855
# 2022-04-22       -0.011107      -0.004592     -0.002510      -0.007741
#
#             TIGER 가격조정  KODEX 고배당  KODEX 인버스  KODEX 200
# 날짜
# 2019-04-16         NaN        NaN        NaN        NaN
# 2019-04-17   -0.005305   0.003240   0.000000  -0.000677
# 2019-04-18   -0.013905  -0.006459   0.016043  -0.015924
# 2019-04-19   -0.000386   0.002709  -0.000752   0.000172
# 2019-04-22    0.001353   0.000000   0.000752   0.000172
# ...                ...        ...        ...        ...
# 2022-04-18   -0.004019   0.002351  -0.001131   0.000838
# 2022-04-19    0.007645   0.006567  -0.011325   0.011720
# 2022-04-20    0.002950   0.001864   0.001145  -0.000827
# 2022-04-21    0.005043   0.000930  -0.004577   0.004417
# 2022-04-22   -0.006063   0.003253   0.011494  -0.010994
#
# [747 rows x 12 columns]

# %%
(prices.pct_change() * df_weight_ret_dyn_fast).sum(axis=1)[1:]
# Out:
# 날짜
# 2019-04-17   -0.000677
# 2019-04-18   -0.014510
# 2019-04-19    0.000018
# 2019-04-22    0.000083
# 2019-04-23    0.001140
#                 ...
# 2022-04-18    0.001141
# 2022-04-19    0.006806
# 2022-04-20    0.000362
# 2022-04-21    0.002760
# 2022-04-22   -0.010206
# Length: 746, dtype: float64

# %%
df_ret_combine_index['ret_dyn_fast']
# Out:
# 날짜
# 2019-04-17   -0.000677
# 2019-04-18   -0.014510
# 2019-04-19    0.000018
# 2019-04-22    0.000083
# 2019-04-23    0.001140
#                 ...
# 2022-04-18    0.001141
# 2022-04-19    0.006806
# 2022-04-20    0.000362
# 2022-04-21    0.002760
# 2022-04-22   -0.010206
# Name: ret_dyn_fast, Length: 746, dtype: float64

# %%
# 데이터 체크 (거의 같음)
((prices.pct_change() * df_weight_ret_dyn_fast).sum(axis=1)[1:] - df_ret_combine_index['ret_dyn_fast']).sum()
# Out:
# -2.0816681711721685e-17
